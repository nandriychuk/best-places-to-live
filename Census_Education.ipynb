# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census

# %%
# Census API Key
api_key ="8b66e243a051edf8e014fc8c607957c8375ecf4c"
c = Census(api_key, year=2017)

# %%
#  Get census data
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E","B17001_002E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                     "B01002_001E": "Median Age",
                                     "B19013_001E": "Household Income",
                                     "B19301_001E": "Per Capita Income",
                                     "B17001_002E": "Poverty Count",
                                     "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd["Poverty Rate"] = 100 * \
   census_pd["Poverty Count"].astype(
       int) / census_pd["Population"].astype(int)

# Final DataFrame
census_pd = census_pd[["Zipcode", "Population", "Median Age", "Household Income",
                      "Per Capita Income", "Poverty Count", "Poverty Rate"]]

# Visualize
print(len(census_pd))
census_pd.head()
# Out:
# 33120
#   Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0   00601     17599.0        38.9           11757.0             7041.0
# 1   00602     39209.0        40.9           16190.0             8978.0
# 2   00603     50135.0        40.4           16645.0            10897.0
# 3   00606      6304.0        42.8           13387.0             5960.0
# 4   00610     27590.0        41.4           18741.0             9266.0
#
#    Poverty Count  Poverty Rate
# 0        11282.0     64.105915
# 1        20428.0     52.100283
# 2        25176.0     50.216416
# 3         4092.0     64.911168
# 4        12553.0     45.498369

# %%
# Run Census Search to retrieve data on all states
# Note the addition of "B23025_005E" for unemployment count
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B15003_002E",
                          "B15003_022E",
                          "B23025_005E"), {'for': 'zip code tabulation area:*'} ) #{'for': 'state:*'}

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B15003_002E": "Education None",
                                      "B15003_022E": "Education Bachelors",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "Name", "zip code tabulation area": "Zipcode"}) #"state": "State"

# Add in Poverty Rate (Poverty Count / Population)
# census_pd["Poverty Rate"] = 100 * \
#     census_pd["Poverty Count"].astype(
#         int) / census_pd["Population"].astype(int)

# Add in Employment Rate (Employment Count / Population)
census_pd["Unemployment Rate"] = 100 * \
    census_pd["Unemployment Count"].astype(
        int) / census_pd["Population"].astype(int)
# Percent of people with no schooling
census_pd["Education None_percent"] = (census_pd["Education None"].astype(int) / census_pd["Population"].astype(int)) * 100
census_pd["Education Bachelors_percent"] = (census_pd["Education Bachelors"].astype(int) / census_pd["Population"].astype(int)) * 100

# census_pd["Education None_percent"] = census_pd["Education None_percent"].sort(ascending=False)

# Final DataFrame
census_pd = census_pd[["Zipcode", "Name", "Population", "Median Age", "Household Income",
                       "Per Capita Income", "Education None", "Education Bachelors", "Unemployment Rate", "Education None_percent","Education Bachelors_percent"]]

census_pd.head()
# Out:
#   Zipcode         Name  Population  Median Age  Household Income  \
# 0   00601  ZCTA5 00601     17599.0        38.9           11757.0
# 1   00602  ZCTA5 00602     39209.0        40.9           16190.0
# 2   00603  ZCTA5 00603     50135.0        40.4           16645.0
# 3   00606  ZCTA5 00606      6304.0        42.8           13387.0
# 4   00610  ZCTA5 00610     27590.0        41.4           18741.0
#
#    Per Capita Income  Education None  Education Bachelors  Unemployment Rate  \
# 0             7041.0           536.0               1787.0          13.943974
# 1             8978.0           843.0               3694.0           6.473004
# 2            10897.0          1056.0               5858.0           7.156677
# 3             5960.0           214.0                321.0           3.236041
# 4             9266.0           494.0               2268.0           5.342515
#
#    Education None_percent  Education Bachelors_percent
# 0                3.045628                    10.153986
# ...

# %%
# Run Census Search to retrieve data on all states
# Note the addition of "B23025_005E" for unemployment count
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B15003_002E",
                          "B15003_018E",
                          "B15003_017E",
                          "B15003_021E",
                          "B15003_022E",
                          "B15003_023E",
                          "B15003_024E",
                          "B15003_025E",                          
                          "B23025_005E"), {'for': 'zip code tabulation area:*'} ) #{'for': 'state:*'}

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B15003_002E": "Education None",
                                      "B15003_018E": "Education GED",
                                      "B15003_017E": "Education High School",
                                      "B15003_021E": "Education Associates",
                                      "B15003_022E": "Education Bachelors",
                                      "B15003_023E": "Education Masters",
                                      "B15003_024E": "Education Professional",                                    
                                      "B15003_025E": "Education Doctorate",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Add in Poverty Rate (Poverty Count / Population)
# census_pd["Poverty Rate"] = 100 * \
#     census_pd["Poverty Count"].astype(
#         int) / census_pd["Population"].astype(int)

# Add in Employment Rate (Employment Count / Population)
census_pd["Unemployment Rate"] = 100 * \
    census_pd["Unemployment Count"].astype(
        int) / census_pd["Population"].astype(int)
# Percentages of people by educational attainment
census_pd["Education None_percent"] = (census_pd["Education None"].astype(int) / census_pd["Population"].astype(int)) * 100
census_pd["Education GED_percent"] = (census_pd["Education GED"].astype(int) / census_pd["Population"].astype(int)) * 100
census_pd["Education High School_percent"] = (census_pd["Education High School"].astype(int) / census_pd["Population"].astype(int)) * 100
census_pd["Education Associates_percent"] = (census_pd["Education Associates"].astype(int) / census_pd["Population"].astype(int)) * 100
census_pd["Education Bachelors_percent"] = (census_pd["Education Bachelors"].astype(int) / census_pd["Population"].astype(int)) * 100
census_pd["Education Masters_percent"] = (census_pd["Education Masters"].astype(int) / census_pd["Population"].astype(int)) * 100
census_pd["Education Professional_percent"] = (census_pd["Education Professional"].astype(int) / census_pd["Population"].astype(int)) * 100
census_pd["Education Doctorate_percent"] = (census_pd["Education Doctorate"].astype(int) / census_pd["Population"].astype(int)) * 100

# Final DataFrame
census_pd = census_pd[["Zipcode", "Name", "Population", "Median Age", "Household Income",
                       "Per Capita Income", "Education None", "Education Bachelors", "Unemployment Rate", "Education None_percent", "Education GED_percent", "Education High School_percent", "Education Associates_percent", "Education Bachelors_percent", "Education Masters_percent", "Education Professional_percent", "Education Doctorate_percent" ]]

census_pd.head()
# Out:
#   Zipcode         Name  Population  Median Age  Household Income  \
# 0   00601  ZCTA5 00601     17599.0        38.9           11757.0
# 1   00602  ZCTA5 00602     39209.0        40.9           16190.0
# 2   00603  ZCTA5 00603     50135.0        40.4           16645.0
# 3   00606  ZCTA5 00606      6304.0        42.8           13387.0
# 4   00610  ZCTA5 00610     27590.0        41.4           18741.0
#
#    Per Capita Income  Education None  Education Bachelors  Unemployment Rate  \
# 0             7041.0           536.0               1787.0          13.943974
# 1             8978.0           843.0               3694.0           6.473004
# 2            10897.0          1056.0               5858.0           7.156677
# 3             5960.0           214.0                321.0           3.236041
# 4             9266.0           494.0               2268.0           5.342515
#
#    Education None_percent  Education GED_percent  \
# 0                3.045628               0.767089
# ...

# %%
# Run Census Search to retrieve data on all states
# Note the addition of "B23025_005E" for unemployment count
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B15003_002E",
                          "B15003_018E",
                          "B15003_017E",
                          "B15003_021E",
                          "B15003_022E",
                          "B15003_023E",
                          "B15003_024E",
                          "B15003_025E",                          
                          "B23025_005E"), {'for': 'state:*'} )
# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B15003_002E": "Education None",
                                      "B15003_018E": "Education GED",
                                      "B15003_017E": "Education High School",
                                      "B15003_021E": "Education Associates",
                                      "B15003_022E": "Education Bachelors",
                                      "B15003_023E": "Education Masters",
                                      "B15003_024E": "Education Professional",                                    
                                      "B15003_025E": "Education Doctorate",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "state"})

# Add in Poverty Rate (Poverty Count / Population)
# census_pd["Poverty Rate"] = 100 * \
#     census_pd["Poverty Count"].astype(int) / census_pd["Population"].astype(int)

# Add in Employment Rate (Employment Count / Population)
census_pd["Unemployment Rate"] = 100 * \
    census_pd["Unemployment Count"].astype(
        int) / census_pd["Population"].astype(int)
# Percentages of people by educational attainment
census_pd["Education None_percent"] = (census_pd["Education None"].astype(int) / census_pd["Population"].astype(int)) * 100
census_pd["Education GED_percent"] = (census_pd["Education GED"].astype(int) / census_pd["Population"].astype(int)) * 100
census_pd["Education High School_percent"] = (census_pd["Education High School"].astype(int) / census_pd["Population"].astype(int)) * 100
census_pd["Education Associates_percent"] = (census_pd["Education Associates"].astype(int) / census_pd["Population"].astype(int)) * 100
census_pd["Education Bachelors_percent"] = (census_pd["Education Bachelors"].astype(int) / census_pd["Population"].astype(int)) * 100
census_pd["Education Masters_percent"] = (census_pd["Education Masters"].astype(int) / census_pd["Population"].astype(int)) * 100
census_pd["Education Professional_percent"] = (census_pd["Education Professional"].astype(int) / census_pd["Population"].astype(int)) * 100
census_pd["Education Doctorate_percent"] = (census_pd["Education Doctorate"].astype(int) / census_pd["Population"].astype(int)) * 100

# Final DataFrame
census_pd = census_pd[["state", "Population", "Median Age", "Household Income",
                       "Per Capita Income", "Education None", "Education Bachelors", "Unemployment Rate", "Education None_percent", "Education GED_percent", "Education High School_percent", "Education Associates_percent", "Education Bachelors_percent", "Education Masters_percent", "Education Professional_percent", "Education Doctorate_percent" ]]

census_pd.head()
# Out:
#          state state  Population  Median Age  Household Income  \
# 0  Puerto Rico    72   3468963.0        40.1           19775.0
# 1      Alabama    01   4850771.0        38.7           46472.0
# 2       Alaska    02    738565.0        33.9           76114.0
# 3      Arizona    04   6809946.0        37.2           53510.0
# 4     Arkansas    05   2977944.0        37.9           43813.0
#
#    Per Capita Income  Education None  Education Bachelors  Unemployment Rate  \
# 0            12081.0         62694.0             426310.0           6.359163
# 1            25746.0         41118.0             503930.0           3.409582
# 2            35065.0          3451.0              88308.0           4.000731
# 3            27964.0         65604.0             802435.0           3.317368
# 4            24426.0         23003.0             280677.0           2.858617
#
#    Education None_percent  Education GED_percent  \
# 0                1.807284               1.802095
# ...
